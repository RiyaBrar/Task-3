# %% [markdown]
# #  GRIP: The Sparks Foundation
# ## Data Science and Business Analytic Intern
# ### Author: Riya
# ## Task 3: Exploratory Data Analysis - Retail
# **In this task we will try to find out the weak areas where we can work to make more profit.**

# %%
#importing the required libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Now we will read our data

# %%
df=pd.read_csv('SampleSuperstore.csv')

# %% [markdown]
# ### Exploring our data

# %%
df #print our data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.head(5) #top 5 rows
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail(5) # bottom 5 rows
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.shape # for the number of rows and columns
# Out:
# (9994, 13)

# %%
df.info() # information about variables and their data types.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.isnull().sum() # whether their is any null entery
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.describe() # statistics of variables
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.corr() # for the correlation
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(df.corr(),cmap='rocket_r',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From this heatmap we deduce that,
# - Sales and profit are moderately related
# - Discount and sales are Negatively correlated
# - Quantity and Profit are less Moderately related

# %%
df['Country'].unique() # the uniue variable value
# Out:
# array(['United States'], dtype=object)

# %%
df=df.drop('Country',axis=1) # as all the data is of united states, so we can drop the variable column country
df.head()
# Out:
#         Ship Mode    Segment             City       State  Postal Code Region  \
# 0    Second Class   Consumer        Henderson    Kentucky        42420  South
# 1    Second Class   Consumer        Henderson    Kentucky        42420  South
# 2    Second Class  Corporate      Los Angeles  California        90036   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %%
df['Category'].value_counts() # for the types of category of the product
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
df['Ship Mode'].value_counts() # for the types of ship mode
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
df['Sub-Category'].value_counts() # for the types of items in Sub-Category
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %% [markdown]
# ### Data Visualizations

# %%
plt.figure(figsize=(20,8))              #
df['State'].value_counts().plot.bar()
plt.xlabel('State',size=14)
plt.xticks(size=10)
plt.ylabel('Number of Orders', size=16)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(5,5))
colors = ['pink', 'lightblue','orange','lightgreen']

df['Ship Mode'].value_counts().plot.pie(shadow = True,colors=colors,explode=(0,0.1,0.1,0.1) ,autopct = '%.2f%%')
#autopct enables you to display the percent value using Python string formatting. 
plt.title('Ship Mode', fontsize = 20)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(7,7))
colors = ['pink', 'lightblue','lightgreen']
df['Category'].value_counts().plot.pie(shadow = True,colors=colors,explode=(0,0.1,0.1) ,autopct = '%.2f%%')
#autopct enables you to display the percent value using Python string formatting. 
plt.title('Category', fontsize = 20)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(9,9))

df.groupby('Sub-Category').sum()['Quantity'].plot.pie(shadow = True ,autopct = '%.2f%%')
#autopct enables you to display the percent value using Python string formatting. 
plt.title('Sub-Category as per Quantity-wise', fontsize = 20)
plt.legend()
plt.show()

# %%
sales=pd.DataFrame(df.groupby('Sub-Category').sum()['Sales'])
sales
# Out:
#                     Sales
# Sub-Category
# Accessories   167380.3180
# Appliances    107532.1610
# Art            27118.7920
# Binders       203412.7330
# Bookcases     114879.9963
# Chairs        328449.1030
# Copiers       149528.0300
# Envelopes      16476.4020
# Fasteners       3024.2800
# Furnishings    91705.1640
# Labels         12486.3120
# Machines      189238.6310
# Paper          78479.2060
# Phones        330007.0540
# Storage       223843.6080
# Supplies       46673.5380
# Tables        206965.5320

# %%
# Visualization of the sales on the bar graph
sales.plot.bar(figsize=(10,5))
plt.title('Sales of sub-category items',size=18)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.scatter("Sub-Category","Profit",c="orange",data=df)
plt.xticks(rotation="vertical", size=10)
plt.xlabel("Sub-Category")
plt.ylabel("profit")
plt.title('Scatter plot of Profits on sub-category items',size=18)
plt.grid()
plt.show()

# %%
profits=pd.DataFrame(df.groupby("Sub-Category").sum()["Profit"])
profits
# Out:
#                   Profit
# Sub-Category
# Accessories   41936.6357
# Appliances    18138.0054
# Art            6527.7870
# Binders       30221.7633
# Bookcases     -3472.5560
# Chairs        26590.1663
# Copiers       55617.8249
# Envelopes      6964.1767
# Fasteners       949.5182
# Furnishings   13059.1436
# Labels         5546.2540
# Machines       3384.7569
# Paper         34053.5693
# Phones        44515.7306
# Storage       21278.8264
# Supplies      -1189.0995
# Tables       -17725.4811

# %%
profits=profits.sort_values('Profit')# sorting profits as sub-category in incresing order
profits
# Out:
#                   Profit
# Sub-Category
# Tables       -17725.4811
# Bookcases     -3472.5560
# Supplies      -1189.0995
# Fasteners       949.5182
# Machines       3384.7569
# Labels         5546.2540
# Art            6527.7870
# Envelopes      6964.1767
# Furnishings   13059.1436
# Appliances    18138.0054
# Storage       21278.8264
# Chairs        26590.1663
# Binders       30221.7633
# Paper         34053.5693
# Accessories   41936.6357
# Phones        44515.7306
# Copiers       55617.8249

# %%
profits.plot.bar(figsize=(10,5))
plt.title('graph of profits on sub-category items',size=18)
plt.grid()
plt.show()

# %%
colours = ['lightgreen', 'pink']
df.groupby('Sub-Category')[['Profit','Sales']].sum().plot.bar(figsize=(10,5),color=colours)
plt.title('Aggregate profits and sales per Sub-Category',size=20)
plt.grid()
plt.show()

# %% [markdown]
# ### Profit per State-wise in decreasing order

# %%
state_profit=pd.DataFrame(df.groupby('State').sum()['Profit'])
state_profit.sort_values('Profit',ascending=False)
# Out:
#                           Profit
# State
# California            76381.3871
# New York              74038.5486
# Washington            33402.6517
# Michigan              24463.1876
# Virginia              18597.9504
# Indiana               18382.9363
# Georgia               16250.0433
# Kentucky              11199.6966
# Minnesota             10823.1874
# Delaware               9977.3748
# New Jersey             9772.9138
# Wisconsin              8401.8004
# Rhode Island           7285.6293
# Maryland               7031.1788
# Massachusetts          6785.5016
# Missouri               6436.2105
# Alabama                5786.8253
# Oklahoma               4853.9560
# Arkansas               4008.6871
# Connecticut            3511.4918
# Nevada                 3316.7659
# Mississippi            3172.9762
# Utah                   2546.5335
# Vermont                2244.9783
# Louisiana              2196.1023
# Nebraska               2037.0942
# Montana                1833.3285
# ...

# %%
plt.figure(figsize=(20,15))
statewise=df.groupby(['State'])['Profit'].sum().nlargest(50)
statewise.plot.bar()
plt.title('Graph of Statewise profit',size=25)
plt.grid()
plt.show()

# %% [markdown]
# ### The analysis above show that State Texas have the lowest Profit whereas California have maximum profit

# %%
plt.figure(figsize=(10,5))
df.groupby('Region').sum()['Profit'].plot.pie(shadow = True ,colors=['pink', 'lightblue','lightgreen','orange'],explode=(0,0,0,0.1),autopct = '%.2f%%')
plt.title('Profit of per-region',size=18)
plt.legend()
plt.show()

# %% [markdown]
# ### This pie chart shows that West Region has the most profit, whereas Central region has the least profit
